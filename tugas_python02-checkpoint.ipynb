# %%
import pandas as pd

# %%
iris=pd.read_csv('http://data.jakarta.go.id/dataset/180ed31f-bc48-4003-9616-5b61c6038850/resource/1ef8de9e-bdd7-424a-ab2c-93aba579430b/download/Laju-Pertumbuhan-PDRB-DKI-Jakarta-Menurut-Pengeluaran-2015-2016.csv')

# %%
iris.head()
# Out:
#    tahun jenis_perbandingan         periode  \
# 0   2015             q to q    Triwulan III
# 1   2016             q to q    Triwulan III
# 2   2015             y on y    Triwulan III
# 3   2016             y on y    Triwulan III
# 4   2015             c to c  Triwulan I-III
#
#                             komponen  persentase
# 0  Pengeluaran Konsumsi Rumah Tangga        2.87
# 1  Pengeluaran Konsumsi Rumah Tangga        2.35
# 2  Pengeluaran Konsumsi Rumah Tangga        5.03
# 3  Pengeluaran Konsumsi Rumah Tangga        5.02
# 4  Pengeluaran Konsumsi Rumah Tangga        5.05

# %%
iris.tail()
# Out:
#     tahun jenis_perbandingan         periode                  komponen  \
# 43   2016             q to q    Triwulan III  Net Ekspor Antar Daerah
# 44   2015             y on y    Triwulan III  Net Ekspor Antar Daerah
# 45   2016             y on y    Triwulan III  Net Ekspor Antar Daerah
# 46   2015             c to c  Triwulan I-III  Net Ekspor Antar Daerah
# 47   2016             c to c  Triwulan I-III  Net Ekspor Antar Daerah
#
#     persentase
# 43      -21.12
# 44      -32.60
# 45       -4.45
# 46      -20.81
# 47      -12.93

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
# tahun                 48 non-null int64
# jenis_perbandingan    48 non-null object
# periode               48 non-null object
# komponen              48 non-null object
# persentase            48 non-null float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.0+ KB

# %%
iris.describe()
# Out:
#              tahun  persentase
# count    48.000000   48.000000
# mean   2015.500000   15.479583
# std       0.505291   86.866267
# min    2015.000000  -32.600000
# 25%    2015.000000   -5.820000
# 50%    2015.500000    2.125000
# 75%    2016.000000    4.285000
# max    2016.000000  516.720000

# %%
iris.groupby('persentase').mean()
# Out:
#             tahun
# persentase
# -32.60       2015
# -31.57       2015
# -21.12       2016
# -20.81       2015
# -13.96       2015
# -12.93       2016
# -12.02       2015
# -11.27       2015
# -9.56        2015
# -8.09        2015
# -7.80        2015
# -6.24        2016
# -5.68        2015
# -4.45        2016
# -3.58        2016
# -2.99        2016
# -1.45        2016
# -0.99        2016
# -0.09        2015
# -0.08        2016
#  0.74        2016
#  0.81        2015
#  1.46        2015
#  1.90        2016
#  2.35        2016
#  2.36        2016
#  2.81        2015
#  2.87        2015
#  2.95        2015
#  2.97        2015
#  3.33        2016
#  3.36        2016
#  3.46        2015
#  3.54        2015
#  3.73        2015
#  4.04        2016
#  5.02        2016
#  5.03        2015
#  5.05        2015
#  5.21        2016
#  7.20        2015
#  8.89        2016
#  9.57        2016
#  11.02       2016
#  11.56       2015
#  15.26       2016
#  307.09      2016
#  516.72      2016

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,8))
plt.plot(iris['tahun'], label='tahun')
plt.plot(iris['persentase'], label='persentase')
plt.xlabel('data count')
plt.ylabel('value')
plt.legend()
plt.show()
